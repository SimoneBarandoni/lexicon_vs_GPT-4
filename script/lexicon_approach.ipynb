# %%
import pandas as pd
import re
from trieregex import TrieRegEx as TRE
import spacy
nlp = spacy.load('en_core_web_sm')
# Out:
# D:\Anaconda3\lib\site-packages\spacy\util.py:877: UserWarning: [W095] Model 'en_core_web_sm' (3.1.0) was trained with spaCy v3.1 and may not be 100% compatible with the current version (3.5.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
# lemmatization function
def lemma(lista):
    lemmatiz = []
    for i in lista:
        doc = nlp(i)
        tokens = []
        for token in doc:
            tokens.append(token)
        lemmatized_sentence = " ".join([token.lemma_ for token in doc])
        lemmatiz.append(lemmatized_sentence)
    return lemmatiz

# %%
# import the software reviews dataset (already lemmatized)
df = pd.read_excel(r'..\data\software_review.xlsx')
df = df[["text"]]
df = df.reset_index(drop=True)
df.head(5)
# Out:
#                                                 text
# 0  nice and easy but folder create function be no...
# 1  no don t install this in your mobile not at al...
# 2  very speedy app easy to use app that be quick ...
# 3  I absolutely love this app I have try other ap...
# 4  I be happy with the app but I have one problem...

# %%
# import the lexicon of customer needs (the stemming of system quality attributes)
gaz_need = pd.read_excel(r"..\data\system_q_a.xlsx")
gaz_need.head(5)
# Out:
#           word
# 0       access
# 1    accountab
# 2       accura
# 3        adapt
# 4  administrab

# %%
# import the lexicon of user categories
gaz_user = pd.read_excel(r"..\data\user_lexicon.xlsx")

# lemmatization
gaz_user["user"] = lemma(gaz_user["user"])
gaz_user.head(5)
# Out:
#                              user
# 0              technical director
# 1  metal drawing machine operator
# 2      precision device inspector
# 3   air traffic safety technician
# 4     hospitality revenue manager

# %% [markdown]
# <h3> Customer needs extraction </h3>

# %%
pattern = [x.lower() for x in gaz_need["word"].tolist()]
pattern = list(set(pattern))
# Initialize class instance
tre = TRE()

# Add word(s)
tre = TRE(*pattern)

# Create regex pattern from the trie
regex_for_words = tre.regex()
regex_for_words_with_b = f'\\b{regex_for_words}\\b'

# %%
extracted_concepts = []
extracted_concepts_string = []
for i in df["text"]:
    if type(i) == float:
        found_concept = []
    else:
        found_concept = re.findall(regex_for_words, i)
    extracted_concepts_string.append(",".join(list(set(found_concept))))
    extracted_concepts.append(found_concept)

# %%
extracted_concepts
# Out:
# [['availab'],
#  ['mobil'],
#  ['effecti'],
#  ['availab'],
#  ['secur', 'secur'],
#  ['access', 'secur', 'availab'],
#  ['availab'],
#  ['usab'],
#  ['safe'],
#  ['access'],
#  ['availab'],
#  ['access'],
#  ['secur'],
#  ['simpl'],
#  ['understandab'],
#  ['simpl',
#   'availab',
#   'effici',
#   'reliab',
#   'failure',
#   'predictab',
#   'reliab',
#   'simpl',
#   'effici',
#   'effecti',
#   'failure',
#   'simpl'],
#  ['access'],
#  ['availab'],
#  ['reliab'],
#  ['availab'],
#  ['reliab'],
#  ['access'],
#  ['traceab',
#   'access',
#   'access',
#   'access',
#   'scalab',
#   'scalab',
#   'resili',
#   'scalab',
#   'access',
#   'access',
#   'access'],
#  ['effici'],
#  ['failure'],
#  ['effecti'],
#  ['secur'],
#  ['simpl'],
#  ['access'],
#  ['safe'],
#  ['stab', 'mobil'],
#  ['usab'],
#  ['secur', 'access'],
#  ['secur'],
#  ['availab', 'access'],
#  ['secur'],
#  ['availab'],
#  ['simpl'],
#  ['safe', 'secur'],
#  ['simpl'],
#  ['secur'],
#  ['simpl',
#   'access',
#   'effecti',
#   'access',
#   'effecti',
#   'access',
#   'access',
#   'access',
#   'secur',
#   'simpl',
#   'secur',
#   'access'],
#  ['access', 'access', 'access', 'access'],
#  ['mobil', 'access', 'mobil'],
#  ['secur'],
#  ['availab'],
#  ['simpl', 'simpl', 'availab', 'simpl', 'effici', 'simpl', 'effici', 'flexib'],
#  ['effici'],
#  ['simpl'],
#  ['access'],
#  ['availab'],
#  ['reliab'],
#  ['secur', 'secur'],
#  ['stab'],
#  ['secur'],
#  ['failure'],
#  ['availab'],
#  ['usab'],
#  ['accura'],
#  ['fault'],
#  ['access'],
#  ['access'],
#  ['reliab'],
#  ['access', 'availab'],
#  ['accountab'],
#  ['simpl'],
#  ['access'],
#  ['reliab'],
#  ['secur'],
#  ['access'],
#  ['compatib'],
#  ['secur'],
#  ['reliab', 'mobil', 'responsiv'],
#  ['robust'],
#  ['secur'],
#  ['availab'],
#  ['credib'],
#  ['simpl'],
#  ['mobil'],
#  ['reliab', 'compatib'],
#  ['availab'],
#  ['availab'],
#  ['access'],
#  ['secur', 'safe', 'correct'],
#  ['usab'],
#  ['access'],
#  ['secur', 'secur'],
#  ['secur'],
#  ['safe'],
#  ['fault'],
#  ['secur'],
#  ['availab'],
#  ['simpl', 'usab'],
#  ['reliab'],
#  ['safe'],
#  ['simpl'],
#  ['credib'],
#  ['secur'],
#  ['availab', 'availab'],
#  ['mobil'],
#  ['secur'],
#  ['mobil', 'mobil'],
#  ['simpl'],
#  ['secur'],
#  ['secur'],
#  ['secur', 'access'],
#  ['availab'],
#  ['simpl'],
#  ['simpl'],
#  ['access'],
#  ['simpl'],
#  ['reliab', 'reliab'],
#  ['access'],
#  ['effici'],
#  ['secur'],
#  ['availab'],
#  ['usab'],
#  ['availab'],
#  ['safe'],
#  ['secur'],
#  ['reliab'],
#  ['access', 'access', 'access'],
#  ['secur'],
#  ['mobil'],
#  ['secur'],
#  ['access'],
#  ['failure'],
#  ['availab'],
#  ['access'],
#  ['availab'],
#  ['simpl'],
#  ['simpl'],
#  ['mobil', 'scalab'],
#  ['usab'],
#  ['availab'],
#  ['secur', 'safe', 'secur'],
#  ['availab'],
#  ['simpl'],
#  ['flexib'],
#  ['availab'],
#  ['usab'],
#  ['availab'],
#  ['credib'],
#  ['access'],
#  ['access', 'mobil'],
#  ['access'],
#  ['simpl',
#   'effici',
#   'availab',
#   'availab',
#   'effici',
#   'failure',
#   'simpl',
#   'failure'],
#  ['stab'],
#  ['affordab'],
#  ['simpl'],
#  ['mobil'],
#  ['availab'],
#  ['safe'],
#  ['mobil', 'mobil', 'mobil'],
#  ['simpl'],
#  ['responsiv'],
#  ['mobil'],
#  ['reliab'],
#  ['effici'],
#  ['access'],
#  ['secur'],
#  ['access'],
#  ['availab'],
#  ['safe'],
#  ['simpl'],
#  ['usab', 'mobil'],
#  ['safe'],
#  ['secur'],
#  ['reliab', 'secur', 'mobil'],
#  ['safe'],
#  ['flexib', 'access', 'simpl', 'secur', 'simpl'],
#  ['simpl'],
#  ['usab'],
#  ['mobil', 'fault'],
#  ['safe'],
#  ['safe'],
#  ['secur', 'availab', 'access'],
#  ['secur'],
#  ['availab'],
#  ['agil'],
#  ['secur'],
#  ['simpl'],
#  ['secur'],
#  ['availab'],
#  ['access'],
#  ['safe'],
#  ['access'],
#  ['secur'],
#  ['effecti', 'simpl'],
#  ['access'],
#  ['secur', 'access'],
#  ['mobil'],
#  ['availab'],
#  ['access', 'mobil'],
#  ['access'],
#  ['secur', 'secur', 'secur', 'flexib'],
#  ['effecti', 'secur', 'fault', 'secur', 'stab'],
#  ['safe'],
#  ['simpl'],
#  ['availab'],
#  ['access'],
#  ['availab', 'access'],
#  ['secur', 'secur'],
#  ['secur'],
#  ['secur'],
#  ['secur'],
#  ['availab'],
#  ['safe'],
#  ['secur'],
#  ['usab'],
#  ['availab'],
#  ['simpl'],
#  ['availab', 'simpl', 'predictab', 'scalab', 'predictab', 'predictab'],
#  ['availab'],
#  ['simpl', 'safe'],
#  ['secur'],
#  ['availab'],
#  ['secur'],
#  ['safe'],
#  ['availab'],
#  ['access'],
#  ['reliab', 'mobil'],
#  ['safe'],
#  ['mobil'],
#  ['availab'],
#  ['secur'],
#  ['access'],
#  ['mobil', 'safe', 'secur', 'availab'],
#  ['usab'],
#  ['usab', 'mobil'],
#  ['secur'],
#  ['reliab'],
#  ['simpl'],
#  ['mobil'],
#  ['safe'],
#  ['safe'],
#  ['safe', 'secur'],
#  ['usab'],
#  ['access'],
#  ['availab', 'availab'],
#  ['access', 'reliab'],
#  ['stab'],
#  ['secur', 'safe', 'secur'],
#  ['secur', 'secur'],
#  ['secur', 'stab'],
#  ['access'],
#  ['safe', 'access', 'access'],
#  ['access'],
#  ['access'],
#  ['mobil'],
#  ['mobil', 'access', 'secur'],
#  ['correct'],
#  ['simpl', 'safe'],
#  ['secur'],
#  ['secur'],
#  ['access'],
#  ['mobil'],
#  ['simpl'],
#  ['availab'],
#  ['reliab', 'availab', 'availab', 'extensib', 'correct', 'scalab', 'adapt'],
#  ['access'],
#  ['access'],
#  ['simpl',
#   'simpl',
#   'flexib',
#   'access',
#   'mobil',
#   'simpl',
#   'safe',
#   'availab',
#   'access',
#   'access',
#   'effecti',
#   'secur',
#   'stab',
#   'access'],
#  ['simpl'],
#  ['simpl', 'correct'],
#  ['secur', 'availab', 'access'],
#  ['access'],
#  ['access'],
#  ['secur', 'secur'],
#  ['mobil'],
#  ['scalab', 'availab', 'access'],
#  ['secur'],
#  ['responsiv'],
#  ['correct', 'correct'],
#  ['secur'],
#  ['secur'],
#  ['access'],
#  ['secur'],
#  ['reliab'],
#  ['sustainab'],
#  ['failure'],
#  ['correct'],
#  ['reliab', 'secur'],
#  ['secur'],
#  ['simpl'],
#  ['fault'],
#  ['availab'],
#  ['secur'],
#  ['mobil'],
#  ['safe'],
#  ['simpl'],
#  ['availab', 'mobil'],
#  ['reliab'],
#  ['adapt', 'simpl', 'flexib', 'adapt'],
#  ['mobil', 'mobil'],
#  ['secur'],
#  ['availab', 'access'],
#  ['reliab'],
#  ['mobil'],
#  ['stab'],
#  ['fault'],
#  ['flexib', 'secur', 'secur', 'reliab'],
#  ['reliab'],
#  ['usab'],
#  ['mobil', 'mobil'],
#  ['access'],
#  ['availab', 'availab'],
#  ['availab'],
#  ['availab'],
#  ['secur'],
#  ['availab', 'stab'],
#  ['credib'],
#  ['simpl', 'secur'],
#  ['effici', 'safe'],
#  ['simpl'],
#  ['failure'],
#  ['secur'],
#  ['mobil'],
#  ['simpl'],
#  ['responsiv', 'simpl'],
#  ['secur'],
#  ['mobil', 'mobil'],
#  ['simpl'],
#  ['simpl'],
#  ['usab'],
#  ['availab', 'simpl'],
#  ['safe'],
#  ['safe'],
#  ['reliab'],
#  ['robust',
#   'simpl',
#   'availab',
#   'effecti',
#   'effecti',
#   'simpl',
#   'simpl',
#   'resili',
#   'effecti',
#   'availab',
#   'simpl',
#   'availab',
#   'correct'],
#  ['access', 'access'],
#  ['simpl'],
#  ['simpl', 'robust', 'reliab'],
#  ['availab'],
#  ['mobil'],
#  ['reliab'],
#  ['simpl'],
#  ['secur', 'access'],
#  ['availab', 'mobil', 'availab', 'mobil'],
#  ['usab'],
#  ['usab'],
#  ['mobil', 'availab'],
#  ['fault'],
#  ['simpl'],
#  ['access'],
#  ['failure',
#   'availab',
#   'availab',
#   'availab',
#   'failure',
#   'failure',
#   'failure',
#   'reliab',
#   'failure',
#   'failure'],
#  ['mobil', 'mobil'],
#  ['affordab'],
#  ['mobil'],
#  ['effecti'],
#  ['availab'],
#  ['stab'],
#  ['safe', 'safe'],
#  ['availab'],
#  ['mobil'],
#  ['stab'],
#  ['access'],
#  ['mobil'],
#  ['secur'],
#  ['effecti'],
#  ['access'],
#  ['fault'],
#  ['usab', 'mobil', 'usab'],
#  ['effici'],
#  ['secur'],
#  ['simpl', 'effici'],
#  ['access'],
#  ['stab'],
#  ['secur'],
#  ['secur', 'availab'],
#  ['safe'],
#  ['secur'],
#  ['mobil'],
#  ['usab'],
#  ['simpl'],
#  ['access'],
#  ['simpl', 'simpl', 'effecti'],
#  ['secur', 'access'],
#  ['safe'],
#  ['correct'],
#  ['simpl'],
#  ['availab'],
#  ['accura'],
#  ['fault', 'access', 'secur'],
#  ['mobil'],
#  ['simpl'],
#  ['safe'],
#  ['access'],
#  ['fault'],
#  ['stab'],
#  ['mobil', 'mobil', 'mobil'],
#  ['simpl'],
#  ['safe'],
#  ['safe'],
#  ['robust'],
#  ['simpl'],
#  ['availab'],
#  ['safe'],
#  ['mobil', 'mobil', 'credib'],
#  ['stab', 'responsiv'],
#  ['usab'],
#  ['secur'],
#  ['access'],
#  ['secur'],
#  ['availab', 'availab'],
#  ['usab'],
#  ['secur'],
#  ['simpl'],
#  ['fault'],
#  ['secur'],
#  ['safe'],
#  ['availab', 'simpl', 'secur', 'availab', 'availab'],
#  ['simpl'],
#  ['simpl'],
#  ['reliab'],
#  ['access'],
#  ['mobil'],
#  ['mobil'],
#  ['reliab'],
#  ['access'],
#  ['simpl'],
#  ['reliab', 'reliab', 'affordab', 'reliab', 'reliab', 'simpl'],
#  ['simpl', 'simpl', 'availab', 'effecti', 'accura'],
#  ['simpl'],
#  ['responsiv'],
#  ['adapt', 'effecti', 'adapt', 'simpl', 'effecti', 'effecti', 'simpl'],
#  ['safe', 'secur', 'secur'],
#  ['usab'],
#  ['access'],
#  ['stab'],
#  ['usab'],
#  ['mobil'],
#  ['credib'],
#  ['availab'],
#  ['access', 'access'],
#  ['access'],
#  ['access'],
#  ['secur', 'simpl'],
#  ['availab'],
#  ['reliab', 'access'],
#  ['availab'],
#  ['stab'],
#  ['secur'],
#  ['access'],
#  ['availab'],
#  ['access'],
#  ['simpl'],
#  ['secur'],
#  ['mobil'],
#  ['access'],
#  ['safe'],
#  ['secur', 'fault', 'secur'],
#  ['secur', 'secur', 'reliab'],
#  ['robust', 'safe', 'secur'],
#  ['safe'],
#  ['simpl'],
#  ['secur'],
#  ['safe', 'access'],
#  ['safe', 'secur'],
#  ['access'],
#  ['mobil'],
#  ['availab'],
#  ['credib'],
#  ['secur'],
#  ['mobil', 'mobil'],
#  ['mobil'],
#  ['responsiv'],
#  ['simpl'],
#  ['mobil'],
#  ['mobil'],
#  ['secur'],
#  ['simpl'],
#  ['access'],
#  ['availab'],
#  ['safe'],
#  ['mobil'],
#  ['access'],
#  ['safe'],
#  ['stab'],
#  ['mobil'],
#  ['credib', 'secur'],
#  ['safe'],
#  ['effici'],
#  ['secur', 'availab'],
#  ['mobil'],
#  ['fault'],
#  ['availab', 'simpl', 'simpl', 'simpl'],
#  ['availab'],
#  ['availab'],
#  ['simpl'],
#  ['simpl'],
#  ['effecti'],
#  ['access', 'vulnerab'],
#  ['mobil'],
#  ['reliab'],
#  ['safe'],
#  ['effecti'],
#  ['access'],
#  ['access'],
#  ['access', 'safe'],
#  ['access'],
#  ['safe'],
#  ['effici'],
#  ['access'],
#  ['secur'],
#  ['access'],
#  ['availab'],
#  ['availab'],
#  ['access'],
#  ['secur', 'mobil'],
#  ['effici'],
#  ['mobil'],
#  ['effici'],
#  ['safe'],
#  ['accura', 'access', 'reliab'],
#  ['secur'],
#  ['simpl'],
#  ['secur'],
#  ['secur'],
#  ['effecti'],
#  ['safe'],
#  ['mobil', 'access', 'access'],
#  ['availab', 'availab'],
#  ['mobil'],
#  ['credib'],
#  ['reliab'],
#  ['accura'],
#  ['effici'],
#  ['availab'],
#  ['usab'],
#  ['secur', 'secur'],
#  ['simpl'],
#  ['credib'],
#  ['mobil'],
#  ['secur'],
#  ['mobil'],
#  ['usab'],
#  ['safe'],
#  ['responsiv'],
#  ['failure', 'simpl'],
#  ['availab'],
#  ['compatib'],
#  ['mobil', 'mobil', 'access'],
#  ['access'],
#  ['access'],
#  ['credib'],
#  ['secur'],
#  ['mobil'],
#  ['access'],
#  ['access'],
#  ['secur', 'secur', 'secur', 'secur', 'access', 'recoverab', 'secur'],
#  ['reliab'],
#  ['availab'],
#  ['access'],
#  ['customizab', 'reliab'],
#  ['reliab'],
#  ['access'],
#  ['mobil'],
#  ['availab'],
#  ['secur'],
#  ['secur'],
#  ['effici', 'secur'],
#  ['simpl'],
#  ['access'],
#  ['secur', 'safe'],
#  ['mobil', 'mobil'],
#  ['mobil'],
#  ['availab'],
#  ['mobil'],
#  ['responsiv'],
#  ['secur', 'secur'],
#  ['simpl'],
#  ['mobil'],
#  ['stab'],
#  ['reliab'],
#  ['access'],
#  ['simpl', 'simpl'],
#  ['simpl', 'availab', 'adapt'],
#  ['effecti'],
#  ['compatib'],
#  ['access'],
#  ['access'],
#  ['secur'],
#  ['availab'],
#  ['secur'],
#  ['simpl',
#   'effecti',
#   'failure',
#   'access',
#   'mobil',
#   'simpl',
#   'simpl',
#   'availab',
#   'accura',
#   'reliab',
#   'reliab',
#   'simpl'],
#  ['simpl'],
#  ['simpl'],
#  ['mobil'],
#  ['usab'],
#  ['availab'],
#  ['resili',
#   'availab',
#   'failure',
#   'reliab',
#   'failure',
#   'failure',
#   'failure',
#   'simpl',
#   'resili',
#   'failure',
#   'availab',
#   'access',
#   'availab',
#   'access',
#   'reliab',
#   'effici',
#   'reliab'],
#  ['safe'],
#  ['safe'],
#  ['usab'],
#  ['fault', 'vulnerab', 'secur', 'mobil'],
#  ['safe'],
#  ['secur'],
#  ['mobil'],
#  ['credib'],
#  ['effici', 'secur', 'access'],
#  ['mobil'],
#  ['mobil'],
#  ['secur'],
#  ['simpl'],
#  ['secur'],
#  ['mobil'],
#  ['access', 'access'],
#  ['secur'],
#  ['portab'],
#  ['simpl'],
#  ['fault'],
#  ['secur'],
#  ['availab'],
#  ['usab'],
#  ['simpl'],
#  ['availab'],
#  ['simpl', 'effici'],
#  ['usab'],
#  ['usab'],
#  ['availab'],
#  ['mobil'],
#  ['safe'],
#  ['secur'],
#  ['simpl', 'secur'],
#  ['secur'],
#  ['mobil'],
#  ['mobil'],
#  ['usab'],
#  ['availab'],
#  ['secur'],
#  ['accura', 'access'],
#  ['safe', 'availab'],
#  ['mobil'],
#  ['predictab', 'effecti', 'simpl'],
#  ['mobil'],
#  ['fault'],
#  ['access'],
#  ['reliab'],
#  ['simpl'],
#  ['mobil', 'mobil', 'availab', 'availab'],
#  ['availab'],
#  ['mobil', 'mobil'],
#  ['secur'],
#  ['availab'],
#  ['secur'],
#  ['secur'],
#  ['reliab', 'availab'],
#  ['simpl', 'mobil'],
#  ['simpl'],
#  ['availab', 'availab', 'reliab'],
#  ['simpl'],
#  ['mobil'],
#  ['secur', 'access', 'mobil'],
#  ['secur'],
#  ['mobil'],
#  ['availab'],
#  ['secur'],
#  ['mobil'],
#  ['mobil'],
#  ['simpl'],
#  ['availab'],
#  ['availab', 'secur'],
#  ['mobil'],
#  ['resili'],
#  ['access'],
#  ['mobil', 'mobil'],
#  ['secur'],
#  ['mobil', 'reliab'],
#  ['reliab'],
#  ['access', 'access'],
#  ['availab', 'availab'],
#  ['access'],
#  ['simpl'],
#  ['availab', 'access'],
#  ['mobil'],
#  ['mobil'],
#  ['safe'],
#  ['availab'],
#  ['availab'],
#  ['simpl', 'simpl'],
#  ['usab'],
#  ['secur', 'secur'],
#  ['safe'],
#  ['simpl'],
#  ['effici'],
#  ['stab'],
#  ['usab'],
#  ['availab'],
#  ['usab'],
#  ['simpl'],
#  ['mobil'],
#  ['access'],
#  ['mobil'],
#  ['reliab'],
#  ['safe'],
#  ['correct'],
#  ['safe'],
#  ['availab'],
#  ['safe'],
#  ['simpl'],
#  ['secur'],
#  ['safe'],
#  ['failure', 'simpl', 'effecti', 'correct'],
#  ['simpl'],
#  ['secur'],
#  ['access'],
#  ['simpl'],
#  ['effici'],
#  ['secur'],
#  ['availab', 'mobil'],
#  ['safe'],
#  ['fault'],
#  ['availab'],
#  ['mobil'],
#  ['secur'],
#  ['effecti'],
#  ['mobil'],
#  ['correct', 'reliab'],
#  ['simpl'],
#  ['simpl'],
#  ['mobil'],
#  ['safe'],
#  ['secur', 'safe'],
#  ['reliab'],
#  ['usab', 'access'],
#  ['simpl'],
#  ['secur'],
#  ['simpl', 'reliab'],
#  ['credib', 'credib'],
#  ['availab'],
#  ['safe'],
#  ['effecti'],
#  ['secur'],
#  ['availab'],
#  ['access'],
#  ['stab'],
#  ['simpl'],
#  ['simpl'],
#  ['access', 'access'],
#  ['effecti', 'reliab'],
#  ['simpl'],
#  ['availab'],
#  ['mobil'],
#  ['availab'],
#  ['mobil'],
#  ['simpl'],
#  ['effecti', 'effecti', 'effecti', 'adapt', 'effecti', 'simpl'],
#  ['availab'],
#  ['mobil'],
#  ['effecti'],
#  ['availab'],
#  ['access'],
#  ['safe'],
#  ['usab'],
#  ['access'],
#  ['access'],
#  ['usab'],
#  ['reliab'],
#  ['availab'],
#  ['responsiv'],
#  ['access'],
#  ['secur'],
#  ['effici'],
#  ['responsiv'],
#  ['secur'],
#  ['safe'],
#  ['reliab'],
#  ['simpl'],
#  ['availab', 'secur'],
#  ['availab'],
#  ['reliab'],
#  ['mobil'],
#  ['responsiv'],
#  ['secur'],
#  ['secur'],
#  ['availab'],
#  ['simpl'],
#  ['access'],
#  ['availab'],
#  ['correct'],
#  ['reliab', 'flexib', 'secur', 'access'],
#  ['access', 'safe'],
#  ['fault'],
#  ['access'],
#  ['secur'],
#  ['mobil'],
#  ['secur'],
#  ['mobil'],
#  ['mobil', 'safe'],
#  ['safe'],
#  ['secur', 'access', 'access', 'secur', 'access'],
#  ['availab'],
#  ['secur', 'secur'],
#  ['reliab'],
#  ['mobil'],
#  ['safe'],
#  ['fault'],
#  ['mobil'],
#  ['mobil', 'safe'],
#  ['correct'],
#  ['mobil'],
#  ['access'],
#  ['simpl', 'precis'],
#  ['failure'],
#  ['adapt', 'simpl', 'simpl', 'simpl', 'effici', 'access', 'resili', 'safe'],
#  ['effici'],
#  ['access'],
#  ['safe'],
#  ['mobil'],
#  ['mobil', 'effecti'],
#  ['simpl'],
#  ['mobil', 'mobil'],
#  ['responsiv', 'mobil', 'mobil'],
#  ['credib', 'simpl'],
#  ['access'],
#  ['access'],
#  ['mobil', 'access'],
#  ['access'],
#  ['secur', 'availab'],
#  ['availab', 'availab'],
#  ['safe'],
#  ['reliab'],
#  ['availab'],
#  ['mobil'],
#  ['mobil'],
#  ['access'],
#  ['availab'],
#  ['simpl'],
#  ['mobil'],
#  ['simpl'],
#  ['access'],
#  ['secur'],
#  ['stab'],
#  ['mobil', 'usab', 'mobil'],
#  ['availab'],
#  ['usab'],
#  ['availab'],
#  ['simpl', 'simpl'],
#  ['access'],
#  ['stab'],
#  ['mobil'],
#  ['safe'],
#  ['secur'],
#  ['secur'],
#  ['fault'],
#  ['stab'],
#  ['accountab'],
#  ['availab'],
#  ['reliab'],
#  ['usab'],
#  ['secur', 'secur', 'flexib', 'stab'],
#  ['simpl'],
#  ['access'],
#  ['simpl'],
#  ['effici', 'effici'],
#  ['safe', 'secur'],
#  ['credib'],
#  ['access'],
#  ['simpl'],
#  ['secur'],
#  ['mobil', 'access'],
#  ['safe'],
#  ['simpl'],
#  ['mobil'],
#  ['availab'],
#  ['mobil'],
#  ['mobil'],
#  ['availab'],
#  ['safe'],
#  ['mobil'],
#  ['availab'],
#  ['availab'],
#  ['simpl'],
#  ['safe'],
#  ['safe', 'access'],
#  ['secur', 'access', 'secur'],
#  ['availab'],
#  ['stab'],
#  ['safe'],
#  ['mobil'],
#  ['availab'],
#  ['availab'],
#  ['access', 'access', 'safe'],
#  ['effici'],
#  ['availab', 'secur', 'secur'],
#  ['mobil'],
#  ['simpl'],
#  ['simpl'],
#  ['mobil'],
#  ['safe'],
#  ['sustainab', 'correct'],
#  ['reliab', 'safe'],
#  ['mobil'],
#  ['availab'],
#  ['credib', 'responsiv'],
#  ['fault'],
#  ['usab'],
#  ['mobil'],
#  ['simpl'],
#  ['effecti'],
#  ['availab'],
#  ['mobil'],
#  ['simpl'],
#  ['secur'],
#  ['secur'],
#  ['availab'],
#  ['simpl'],
#  ['mobil'],
#  ['access'],
#  ['secur', 'vulnerab'],
#  ['access'],
#  ['mobil', 'reliab'],
#  ['secur'],
#  ['fault'],
#  ['access'],
#  ['reliab', 'safe', 'access'],
#  ['secur'],
#  ['access'],
#  ['mobil', 'correct'],
#  ['access', 'access'],
#  ['reliab', 'simpl'],
#  ['compatib', 'safe'],
#  ['stab'],
#  ['usab'],
#  ['fault', 'fault'],
#  ['secur'],
#  ['access', 'mobil'],
#  ['simpl'],
#  ['safe', 'secur'],
#  ['access'],
#  ['secur'],
#  ['stab', 'stab'],
#  ['transpar', 'transpar'],
#  ['mobil'],
#  ['usab'],
#  ['simpl'],
#  ['availab'],
#  ['safe'],
#  ['secur'],
#  ['reliab'],
#  ['simpl'],
#  ['safe'],
#  ['effici', 'effecti', 'failure', 'availab'],
#  ['access', 'access'],
#  ['usab'],
#  ['access'],
#  ['reliab'],
#  ['access'],
#  ['simpl'],
#  ['access'],
#  ['access', 'fault'],
#  ['mobil', 'mobil'],
#  ['effecti'],
#  ['mobil'],
#  ['availab', 'mobil'],
#  ['availab'],
#  ['effici'],
#  ['secur'],
#  ['safe'],
#  ['mobil'],
#  ['safe'],
#  ['simpl'],
#  ['simpl'],
#  ['stab',
#   'simpl',
#   'access',
#   'effecti',
#   'mobil',
#   'simpl',
#   'mobil',
#   'flexib',
#   'scalab',
#   'effici'],
#  ['simpl'],
#  ['simpl'],
#  ['simpl'],
#  ['access', 'scalab', 'simpl'],
#  ['safe', 'mobil'],
#  ['mobil', 'mobil'],
#  ['simpl'],
#  ['simpl', 'access'],
#  ['effici'],
#  ['simpl'],
#  ['reliab'],
#  ['effecti', 'adapt', 'adapt'],
#  ['fault'],
#  ['availab'],
#  ['availab'],
#  ['access'],
#  ['access', 'access'],
#  ['credib'],
#  ['availab'],
#  ['simpl'],
#  ['credib'],
#  ['usab'],
#  ['reliab'],
#  ['mobil'],
#  ['reliab', 'simpl'],
#  ['simpl'],
#  ['availab'],
#  ['mobil'],
#  ['mobil'],
#  ['access'],
#  ['availab'],
#  ['effici'],
#  ['access'],
#  ['access'],
#  ['access'],
#  ...]

# %%
df["extracted_needs"] = extracted_concepts_string
df
# Out:
#                                                    text  extracted_needs
# 0     nice and easy but folder create function be no...          availab
# 1     no don t install this in your mobile not at al...            mobil
# 2     very speedy app easy to use app that be quick ...          effecti
# 3     I absolutely love this app I have try other ap...          availab
# 4     I be happy with the app but I have one problem...            secur
# ...                                                 ...              ...
# 1045  hi william could you try to access google driv...           access
# 1046  easy access and compatible within various rang...  access,compatib
# 1047  hi we be very sorry for the trouble first plea...          availab
# 1048  timing be everything in this game and follow m...           reliab
# 1049  it s be yr since I start use this app from my ...           reliab
#
# [1050 rows x 2 columns]

# %% [markdown]
# <h3> User categories extraction </h3>

# %%
pattern = [x.lower() for x in gaz_user["user"].tolist()]
pattern = list(set(pattern))
# Initialize class instance
tre = TRE()

# Add word(s)
tre = TRE(*pattern)

# Create regex pattern from the trie
regex_for_words = tre.regex()
regex_for_words_with_b = f'\\b{regex_for_words}\\b'

# %%
extracted_concepts = []
extracted_concepts_string = []
for i in df["text"]:
    if type(i) == float:
        found_concept = []
    else:
        found_concept = re.findall(regex_for_words, i)
    extracted_concepts_string.append(",".join(list(set(found_concept))))
    extracted_concepts.append(found_concept)

# %%
df["extracted_users"] = extracted_concepts_string
df.head(5)
# Out:
#                                                 text extracted_needs
# 0  nice and easy but folder create function be no...         availab  \
# 1  no don t install this in your mobile not at al...           mobil
# 2  very speedy app easy to use app that be quick ...         effecti
# 3  I absolutely love this app I have try other ap...         availab
# 4  I be happy with the app but I have one problem...           secur
#
#   extracted_users
# 0             man
# 1             man
# 2
# 3
# 4

# %%
# output
df.to_excel(r"..\data\lexicon_output.xlsx")
